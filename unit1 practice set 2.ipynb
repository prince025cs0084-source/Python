# %%
a = int(input("enter first number:"))
b = int(input("enter second number:"))
print("addition:",a+b)
print("subtraction:",a-b)
print("multiplication:", a*b)
print("division:",a/b)
print("floor division:",a//b)
print("exponentiation:",a**b)
# Out:
# enter first number:10
# enter second number:30
# addition: 40
# subtraction: -20
# multiplication: 300
# division: 0.3333333333333333
# floor division: 0
# exponentiation: 1000000000000000000000000000000

# %%
a = int(input("enter a number:"))
a+=10
print("+=10:",a)
a-=5
print("-=",a)
a*=2
print("*=",a)
a/=3
print("/=3")
# Out:
# enter a number:10
# +=10: 20
# -= 15
# *= 30
# /=3

# %%
a = input("enter the number:")
b = input("enter the number:")
print(a==b)
print(a!=b)
print(a>b)
print(a<=b)
# Out:
# enter the number:10
# enter the number:20
# False
# True
# False
# True

# %%
a=int(input("enter the marks1 of student first subject:"))
b=int(input("enter the marks2 of student second subject:"))
print("pass:",a>=35 and b>=35)
print("scholarship:",a>=90 or b>=90)
print("not failed:",not(a<35 or b<35))
# Out:
# enter the marks1 of student first subject:45
# enter the marks2 of student second subject:67
# pass: True
# scholarship: False
# not failed: True

# %%
a=input("sentence:")
b= input("word:")
print(a in b)
# Out:
# sentence:my name is prince
# word:modinagar
# False

# %%
a =(1,2,3)
b= (1,2,3)
c = a
print(a is b)
print(a is c)
# Out:
# False
# True

# %%
a =(1,2,3)
b= (1,2,3)
c = a
print(a is  not b)
print(a is not c)
# Out:
# True
# False

# %%
a = int(input("enter number:"))
b = int(input("enter number:"))
print("and:",a&b)
print("or:",a|b)
# Out:
# enter number:10
# enter number:5
# and: 0
# or: 15

# %%
a = int(input("enter number:"))
b = int(input("enter number:"))
print("xor:",a^b)
print("not:",~a)
# Out:
# enter number:10
# enter number:8
# xor: 2
# not: -11

# %%
n=int(input("n: "))
print("n<<2:",n<<2)
print("n>>2:",n>>2)
# Out:
# n: 10
# n<<2: 40
# n>>2: 2

# %%
a=input("enter the first no:")
b=input("enter the second no:")
c=input("enter the third no:")
print((a>b)and(c>a))
# Out:
# enter the first no:23
# enter the second no:45
# enter the third no:67
# False
