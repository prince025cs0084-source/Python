# %%
name="ramesh"
age=20
city="modinagar"
salary=30000
print("name",name,"age",age,"salary",salary,"city",city)
# Out:
# name ramesh age 20 salary 30000 city modinagar

# %%
a=20
b=30
a,b=b,a
print(a,b)
# Out:
# 30 20

# %%
a=int(input("enter the number:"))
b=int(input("enter the number:"))
print(a)
sum=a+b
print("sum",sum)
# Out:
# enter the number:5
# enter the number:6
# 5
# sum 11

# %%
a=10
b=10.5
c="vikas"
d="True"
print(type(a),type(b),type(c),type(d))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'str'>

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=100
print(a,b,c)
# Out:
# 100 100 100

# %%
a=10
print(a)
del a
print(a)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10780\4104461118.py in <module>
#       2 print(a)
#       3 del a
# ----> 4 print(a)
#
# NameError: name 'a' is not defined

# %%
a=input("enter your age:")
print(f"you are {age} year old.")
# Out:
# enter your age:45
# you are 20 year old.

# %%
first=input("first name:")
last=input("last name:")
full=first+" "+last
print("full name:",full)
# Out:
# first name:prince
# last name:thakur
# full name: prince thakur

# %%
name=input("enter employee name: ")
salary=float(input("enter monthly salary:"))
annual= salary*12
print("annual:",annual)
# Out:
# enter employee name: prince
# enter monthly salary:4500
# annual: 54000.0
