# %%
# 1. Write a program to check:
#     * If a number is positive
#     * If it is even
#       (Use multiple `if`)
# ---
number=int(input('enter the number:'))
if number%2==0:
    print('postive')
else:
    print("odd ")
# Out:
# enter the number:5
# odd

# %%
# 2. Accept student's marks and check:
#     * If marks ≥ 40 → Pass
#     * If marks ≥ 75 → Distinction
# ---
marks=float(input("enter the student marks:"))
if marks>=40:
    print("pass")
if marks>=75:
    print("distinction")
# Out:
# enter the student marks:45
# pass

# %%
# 3. Enter temperature and check:
#     * If temperature > 30 → Hot
#     * If temperature < 15 → Cold
# ---
temp=float(input("enter the check temprature:"))
if temp>30:
    print("hot")
if temp<15:
    print("cold")
# Out:
# enter the check temprature:14
# cold

# %%
# 4. Accept a person's age and check:
#     * If age ≥ 18 → Eligible to vote
#     * If age ≥ 60 → Senior Citizen
# ---
age=int(input('enter the person age:'))
if age>=18:
    print("eligible to vibe")
if age>=60:
    print("senior citizen")
# Out:
# enter the person age:45
# eligible to vibe

# %%
# 5. Enter salary and check:
#     * If salary > ₹30,000 → Eligible for credit card
#     * If salary > ₹50,000 → Eligible for premium card
# ---
salary=float(input("enter the salary:"))
if salary>30000:
    print("Eligible for credit card")
if salary>500000:
    print(" Eligible for premium card")
# Out:
# enter the salary:45000
# Eligible for credit card

# %%
# 6. Enter electricity units consumed and check:
#     * If units > 100 → Apply surcharge
#     * If units > 300 → Apply heavy surcharge
# ---
elec=float(input("enter electricity units consumed:"))
if elec>100:
    print('apply surcharge')
if elec>300:
    print("apply heavy surcharges")
# Out:
# enter electricity units consumed:200
# apply surcharge

# %%
# 7. Accept login details and check:
#     * If username is "admin" → Valid user
#     * If password is "1234" → Valid password
# ---
name=input('enter username  ')
username="admin"
password=1234
if name==username:
    print('valid user')
    passw=input('enter password:')
if passw==password:
    print("valid passward")
# Out:
# enter username  admin
# valid user
# enter password:1234

# %%
# 8. Enter shopping amount and check:
#     * If amount > ₹5,000 → 10% discount
#     * If amount > ₹10,000 → Additional cashback
# ---
amount=int(input('enter the shoping amount'))
if amount>5000:
    print("10% discount")
if amount>10000:
    print("additional cashback")
# Out:
# enter the shoping amount11000
# 10% discount
# additional cashback

# %%
# 9. Enter employee experience and salary:
#     * If experience > 5 years → Bonus
#     * If salary > ₹60,000 → Special allowance
# --
exp=int(input('enter the employee experince:'))
salary=int(input("enter the salary:"))

if  exp>5:
    print("bonus")
if salary>60000:
    print("special allowance")
# Out:
# enter the employee experince:6
# enter the salary:55000
# bonus

# %%
# 10. Enter BMI and heart rate:
#     * If BMI > 25 → Overweight
#     * If heart rate > 100 → High heart rate
# ---
bmi=int(input("enter BMI:"))
hr=int(input("enter the heart rate:"))

if bmi>25:
    print("over weight")
if hr>100:
    print("high heart rate")
else:
    print("error")
# Out:
# enter BMI:35
# enter the heart rate:110
# over weight
# high heart rate

# %%
# 11. Accept loan applicant details:
#     * If income > ₹25,000 → Income eligible
#     * If CIBIL score > 700 → Credit eligible
#     * If age > 21 → Age eligible
#     (Display all eligibility criteria satisfied.)
# ---
income=float(input("enter applicant's income"))
cibil=float(input("Enter applicant's CIBIL score"))
age=int(input("Enter applicant's age"))

if income>25000:
    print("Income eligible")
    if cibil>700:
        print("Credit eligible")
        if age>21:
            print("Age eligible")
            print("All eligibility criteria satisfied")
else:
    print("Error")
# Out:
# enter applicant's income26000
# Enter applicant's CIBIL score800
# Enter applicant's age23
# Income eligible
# Credit eligible
# Age eligible
# All eligibility criteria satisfied

# %%
# 12. Enter student details:
#     * If marks ≥ 85 → Academic scholarship
#     * If sports = yes → Sports scholarship
#     * If income < ₹2,00,000 → Financial aid
#     (Student may get multiple benefits.)
# ---
marks=int(input("enter the marks:"))
sports=input("enter yes/no:")
income=int(input("enter the income:"))

if marks>=85:
    print("acadmic scholarship")
if sports=="yes":
    print("Sports scholarship")
if income<200000:
    print("financial")
else:
    print('error')
# Out:
# enter the marks:90
# enter yes/no:yes
# enter the income:210000
# acadmic scholarship
# Sports scholarship
# error

# %%
# 13. Enter vehicle speed and alcohol level:
#     * If speed > 80 → Overspeeding
#     * If alcohol level > 0.03 → Drunk driving
# ---
speed=int(input("enter vehical speed:"))
alcohol=float(input('enter the drink driving:'))

if speed>80:
    print("overspeeding")
if alcohol>0.03:
    print("drunk driving")
else:
    print("error")
# Out:
# enter vehical speed:81
# enter the drink driving:0.05
# overspeeding
# drunk driving

# %%
# 14. Enter employee details:
#     * If working hours > 40 → Overtime pay
#     * If performance rating ≥ 8 → Performance bonus
#     * I
work=int(input("enter employee details:"))
pr=int(input("enter performance rating:"))

if  work> 40 :
    print('overtime pay')
if pr>=8:
    print("performance rating")
else:
    print("error")
# Out:
# enter employee details:45
# enter performance rating:9
# overtime pay
# performance rating

# %%
# 15. Enter system parameters:
#     * If CPU usage > 80% → High CPU usage
#     * If RAM usage > 70% → High memory usage
#     * If disk space < 20% → Low disk space
# ---
cpu=float(input("enter the CPU usage:"))
ram =float(input("enter the RAM usage:"))
ds=float(input("enter the disk space:"))

if cpu>80:
    print("High CPU usage")
if ram>70:
    print("High memory usage")
if ds <20:
    print("low disk space")
else:
    print("error")
# Out:
# enter the CPU usage:76
# enter the RAM usage:56
# enter the disk space:10
# low disk space
