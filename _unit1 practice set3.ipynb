# %%
a=20
b=9.0
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 20
# 9.0
# <class 'int'>
# <class 'float'>

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# enter the first number:10
# enter the second number:20
# 30
# -10
# 200
# 0.5
# 0
# 10
# 100000000000000000000

# %%
a=10
b=float(a)
print(b)
c=complex(a)
print(c)
# Out:
# 10.0
# (10+0j)

# %%
a=5+2j
print(a)
b=complex(10,3)
print(b)
# Out:
# (5+2j)
# (10+3j)

# %%
a=4.6
b=9.7
c=3.4
sum=a+b+c/3
print(sum)
# Out:
# 15.433333333333332

# %%
a

# %%
a=int(input("enter the number"))
b=float(input("enter the number"))
c=complex(input("enter the number"))
print(type(a))
print(type(b))
print(type(c))
# Out:
# enter the number45
# enter the number9.0
# enter the number5+7j
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
basic_salary=58750
hra=(basic_salary*22)/100
da=(basic_salary*15)/100
pt=2500
gross_salary=basic_salary+hra+da
print(gross_salary)
net_salary=gross_salary-pt
print(net_salary)
print(f"Basic salary={basic_salary}","HRA={hra}","DA={da}","PT={pt}","GROSS SALARY={gross_salary}","NET SALARY={net_salary}")
print(type(net_salary))
# Out:
# 80487.5
# 77987.5
# Basic salary=58750 HRA={hra} DA={da} PT={pt} GROSS SALARY={gross_salary} NET SALARY={net_salary}
# <class 'float'>

# %%
a=245
b=37
c=-128.75
d=pow(a,2)
print(d)
e=abs(c)
print(e)
print(max(a,b,e))
print(min(a,b,e))
aver=(a+b+c)/3.0
print(aver)
# Out:
# 60025
# 128.75
# 245
# 37
# 51.083333333333336

# %%
c1=6+9j
c2=4-7j
a=c1+c2
print(a)
b=c1*c2
print(c)
print(type(c1))
print(type(c2))
# Out:
# (10+2j)
# -128.75
# <class 'complex'>
# <class 'complex'>

# %%
print("="*40)
print("   STUDENT PROFILE     ")
print("="*40)
Name=input("name:")
Age=int(input("age:"))
Course=input("course:")
University=input("Universtiy:")
city=input("city:")
print("="*40)
# Out:
# ...
#    STUDENT PROFILE
# ...
# name:RahulSharma
# age:20
# course:b.tech
# Universtiy:ABC Universtiy
# city:delhi
# ...
