# %%
employee={"name":"amit","department":"cse","salary":450000}
print(employee)
# Out:
# {'name': 'amit', 'department': 'cse', 'salary': 450000}

# %%
employee={"name":"prince","Department":"cse","salary":45000}
employee["email"]="princethakur@gmail .com"
employee["phone number"]=9520092769
print(employee)
# Out:
# {'name': 'prince', 'Department': 'cse', 'salary': 45000, 'email': 'princethakur@gmail .com', 'phone number': 9520092769}

# %%
employee={"name":"prince","Department":"cse","salary":45000}
print("before:",employee)
employee["salary"]=52000
print("after:",employee)
# Out:
# before: {'name': 'prince', 'Department': 'cse', 'salary': 45000}
# after: {'name': 'prince', 'Department': 'cse', 'salary': 52000}

# %%
employee={"name":"prince","Department":"cse","salary":45000,"age":30}
print("original:",employee)
employee.pop("age")
print("after pop age:",employee)
employee.popitem()
print("after popitem:",employee)
# Out:
# original: {'name': 'prince', 'Department': 'cse', 'salary': 45000, 'age': 30}
# after pop age: {'name': 'prince', 'Department': 'cse', 'salary': 45000}
# after popitem: {'name': 'prince', 'Department': 'cse'}

# %%
student={"roll no":101,"name":"rahul","branch":"cse","sem":5}
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['roll no', 'name', 'branch', 'sem'])
# dict_values([101, 'rahul', 'cse', 5])
# dict_items([('roll no', 101), ('name', 'rahul'), ('branch', 'cse'), ('sem', 5)])

# %%
dect={"name":"tarun","age":30,"city":"nanadnagar"}
key=input("input key:")
if key in student:
    print("key found")
    else:
        print("key not found")
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_14264\2603198725.py", line 5
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
student={"roll no":101,"name":"rahul","branch":"cse","sem":5}
print("total pairs:",len(student))
# Out:
# total pairs: 4

# %%
keys=["id","name","age","city"]
values=[101,"ankit",20,"delhi"]
dict=dict(zip(keys,values))
print(dict)
# Out:
# {'id': 101, 'name': 'ankit', 'age': 20, 'city': 'delhi'}

# %%
students={
    1:{"name":"amit","department":"cse","age":20},
2:{"name":"ramesh","department":"cse","age":23},
3: {"name":"mahesh","department":"cse","age":24}
}
print(students)
# Out:
# {1: {'name': 'amit', 'department': 'cse', 'age': 20}, 2: {'name': 'ramesh', 'department': 'cse', 'age': 23}, 3: {'name': 'mahesh', 'department': 'cse', 'age': 24}}

# %%
students={
1:{"name":"prince","branch":"cse","semester":3,"cgpa":7.5},
2:{"name":"rinky","branch":"cse","semester":3,"cgpa":8.5},
3:{"name":"upmanu","branch":"cse","semester":3,"cgpa":9.5}
}
print(students)
# Out:
# {1: {'name': 'prince', 'branch': 'cse', 'semester': 3, 'cgpa': 7.5}, 2: {'name': 'rinky', 'branch': 'cse', 'semester': 3, 'cgpa': 8.5}, 3: {'name': 'upmanu', 'branch': 'cse', 'semester': 3, 'cgpa': 9.5}}
